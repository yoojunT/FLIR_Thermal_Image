# %% [markdown]
# <a name="import"></a>
# ### Import Dependencies

# %%
# open cv
import cv2
# plotting library
import matplotlib.pyplot as plt
import numpy as np

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread('./data/20221113Site/Hours/0730.jpg')

# Convert BGR to RGB color space
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(img)
plt.show()

# %%
# # Convert the image to a NumPy array
# img_array = np.array(img)
# img_array.shape
# Out:
# (512, 640, 3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time

import cv2
from exif import Image

# %%
img_path = './data/20221113Site/Hours/0730.jpg'
with open(img_path, 'rb') as img_file:
    img = Image(img_file)

# %%
img.has_exif
# Out:
# True

# %%
# List all EXIF tags contained in the image
sorted(img.list_all())
# Out:
# ['_exif_ifd_pointer',
#  '_gps_ifd_pointer',
#  'color_space',
#  'components_configuration',
#  'compression',
#  'exif_version',
#  'f_number',
#  'flashpix_version',
#  'focal_length',
#  'focal_plane_resolution_unit',
#  'focal_plane_x_resolution',
#  'focal_plane_y_resolution',
#  'gps_altitude',
#  'gps_altitude_ref',
#  'gps_latitude',
#  'gps_latitude_ref',
#  'gps_longitude',
#  'gps_longitude_ref',
#  'gps_speed',
#  'gps_speed_ref',
#  'gps_timestamp',
#  'gps_track',
#  'gps_track_ref',
#  'gps_version_id',
#  'make',
#  'model',
#  'orientation',
#  'pixel_x_dimension',
#  'pixel_y_dimension',
#  'resolution_unit',
#  'software',
#  'subject_area',
#  'x_resolution',
#  'y_and_c_positioning',
#  'y_resolution']

# %%
# List all methods and attribute tags
dir(img)
# Out:
# ['<unknown EXIF tag 700>',
#  '_exif_ifd_pointer',
#  '_gps_ifd_pointer',
#  '_segments',
#  'color_space',
#  'components_configuration',
#  'compression',
#  'delete',
#  'delete_all',
#  'exif_version',
#  'f_number',
#  'flashpix_version',
#  'focal_length',
#  'focal_plane_resolution_unit',
#  'focal_plane_x_resolution',
#  'focal_plane_y_resolution',
#  'get',
#  'get_all',
#  'get_file',
#  'get_thumbnail',
#  'gps_altitude',
#  'gps_altitude_ref',
#  'gps_latitude',
#  'gps_latitude_ref',
#  'gps_longitude',
#  'gps_longitude_ref',
#  'gps_speed',
#  'gps_speed_ref',
#  'gps_timestamp',
#  'gps_track',
#  'gps_track_ref',
#  'gps_version_id',
#  'has_exif',
#  'list_all',
#  'make',
#  'model',
#  'orientation',
#  'pixel_x_dimension',
#  'pixel_y_dimension',
#  'resolution_unit',
#  'software',
#  'subject_area',
#  'x_resolution',
#  'y_and_c_positioning',
#  'y_resolution']

# %%
# Make of device which captured image
print(f'Make: {img.get("make")}')

# Model of device which captured image
print(f'Model: {img.get("model")}')

# Software involved in uploading and digitizing image
print(f'color_space: {img.get("color_space")}')

# # Name of photographer who took the image
# print(f'Artist: {img.get("artist")}')

# # Original datetime that image was taken (photographed)
# print(f'DateTime (Original): {img.get("datetime_original")}')

# # Details of flash function
# print(f'Flash Details: {img.get("flash")}')
# Out:
# Make: FLIR
# Model: Vue Pro R 640 19mm
# color_space: 1
